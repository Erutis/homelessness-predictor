# %% [markdown]
# # Homelessness Predictor Based on City Budgets

# %% [markdown]
# The purpose of this project is to see if we can predict homelessness by city from the city's budget. The hypothesis here is that something in the way that a city decides to spend its funds will give an insight to a model on how to predict number of homeless.

# %%
import pandas as pd
import numpy as np

# %%
hl = pd.read_csv('Homelessness_Count_-_USA.csv', index_col=0)
hl_us = pd.read_csv('us_data_homelessness_by_year.csv', index_col=0)
fisc = pd.read_csv('fisc_data.csv', index_col=0)

# %%
hl.head()
# Out:
#                  CoC Name  Year                         Attribute Name  Value  \
# CoC Number
# AK-500      Anchorage CoC  2014                   Chronically Homeless    101
# AK-500      Anchorage CoC  2014  Sheltered Homeless People in Families    282
# AK-500      Anchorage CoC  2014                   Homeless Individuals    736
# AK-500      Anchorage CoC  2014            Homeless People in Families    287
# AK-500      Anchorage CoC  2014       Unsheltered Homeless Individuals     48
#
#             Year - Text
# CoC Number
# AK-500             2014
# AK-500             2014
# AK-500             2014
# AK-500             2014
# AK-500             2014

# %%
hl.shape
# Out:
# (25515, 5)

# %%
hl_us.head()
# Out:
#       sheltered  unsheltered   total
# year
# 2007     391401       255857  647258
# 2008     386361       253423  639784
# 2009     403308       226919  630227
# 2010     403543       233534  637077
# 2011     392316       231472  623788

# %%
hl_us.shape
# Out:
# (12, 3)

# %%
fisc.head()
# Out:
#           city_name city_types   id_city  city_population       cpi  \
# year
# 1977  AK: Anchorage       core  22002001           174500  4.044885
# 1978  AK: Anchorage       core  22002001           177000  3.759509
# 1979  AK: Anchorage       core  22002001           179600  3.376308
# 1980  AK: Anchorage       core  22002001           178800  2.974757
# 1981  AK: Anchorage       core  22002001           174431  2.696590
#
#       rev_total_city  rev_general_city  intergovt_rev_city  igr_federal_city  \
# year
# 1977         5342.24           4956.92             2148.77            279.32
# 1978         5948.99           5490.05             2468.11            403.24
# 1979         6158.68           5746.64             2573.34            496.97
# 1980         5654.93           5210.77             2313.62            371.46
# 1981         6192.83           5736.81             2771.43            338.76
#
#       igr_state_city  ...  cash_other_offsets  cash_other_bonds  \
# year                  ...
# 1977         1869.46  ...              178.51            787.93
# 1978         2064.86  ...              187.53           1395.82
# 1979         2076.37  ...              249.03           1812.04
# 1980         1942.16  ...              986.73           1330.72
# 1981         2432.67  ...              977.32           1549.51
#
#       cash_other_other  county_name  id_county  county_population  \
# year
# 1977            691.32          NaN        NaN                NaN
# 1978           1158.01          NaN        NaN                NaN
# 1979           1314.62          NaN        NaN                NaN
# 1980           1572.66          NaN        NaN                NaN
# 1981           1669.55          NaN        NaN                NaN
#
#       relationship_city_school  enrollment  districts_in_city  \
# year
# 1977                       4.0     36855.0                NaN
# 1978                       4.0     36804.0                NaN
# 1979                       4.0     36757.0                NaN
# 1980                       4.0     36008.0                NaN
# 1981                       4.0     34557.0                NaN
#
#       consolidated_govt
# year
# 1977                1.0
# 1978                1.0
# 1979                1.0
# 1980                1.0
# 1981                1.0
#
# [5 rows x 662 columns]

# %%
fisc.shape
# Out:
# (8938, 662)
